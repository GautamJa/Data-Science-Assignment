# %%
import pandas as pd
titanic_dataset=pd.read_csv("/Users/gautam/Downloads/titanic.csv")
titanic_dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(titanic_dataset.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Removing missing values

# %%
titanic_dataset_drop=titanic_dataset.dropna()
print("\nData Set after droping with missing values:")
print(titanic_dataset_drop)
# Out:
# Data Set after droping with missing values:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ...

# %% [markdown]
#  Impute missing value with mean

# %%
df_mean = titanic_dataset
df_mean['Age'].fillna(df_mean['Age'].mean(), inplace=True)

print("\nDataFrame after imputing numerical columns with mean:")
print(df_mean)
# Out:
# DataFrame after imputing numerical columns with mean:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# Impute the missing value with mode

# %%
df_mode = titanic_dataset
df_mode['Embarked'].fillna(df_mode['Embarked'].mode()[0], inplace=True)
df_mode['Cabin'].fillna(df_mode['Cabin'].mode()[0], inplace=True)


print("\nDataFrame after imputing categorical columns with mode:")
print(df_mode)
# Out:
# DataFrame after imputing categorical columns with mode:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# Checking if the data is still missing or not!

# %%
print(titanic_dataset.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, MaxAbsScaler
from sklearn.preprocessing import LabelEncoder

columns_to_scale = ['PassengerId', 'Survived', 'Pclass', 'Age','SibSp','Parch','Fare'] # include numeric value to scale
#standard_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
#robust_scaler = RobustScaler()
#maxabs_scaler = MaxAbsScaler()
#titanic_dataset[columns_to_scale] = standard_scaler.fit_transform(titanic_dataset[columns_to_scale])
titanic_dataset[columns_to_scale] = minmax_scaler.fit_transform(titanic_dataset[columns_to_scale])
#titanic_dataset[columns_to_scale] = robust_scaler.fit_transform(titanic_dataset[columns_to_scale])
#titanic_dataset[columns_to_scale] = maxabs_scaler.fit_transform(titanic_dataset[columns_to_scale])

# Applying Encoding
encoder=LabelEncoder()
titanic_dataset['Embarked'] = encoder.fit_transform(titanic_dataset['Embarked'])
titanic_dataset['Sex'] = encoder.fit_transform(titanic_dataset['Sex'])
print(titanic_dataset)
# Out:
#      PassengerId  Survived  Pclass  \
# 0       0.000000       0.0     1.0
# 1       0.001124       1.0     0.0
# 2       0.002247       1.0     1.0
# 3       0.003371       1.0     0.0
# 4       0.004494       0.0     1.0
# ..           ...       ...     ...
# 886     0.995506       0.0     0.5
# 887     0.996629       1.0     0.0
# 888     0.997753       0.0     1.0
# 889     0.998876       1.0     0.0
# 890     1.000000       0.0     1.0
#
#                                                   Name  Sex       Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  0.271174  0.125
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  0.472229  0.125
# 2                               Heikkinen, Miss. Laina    0  0.321438  0.000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  0.434531  0.125
# 4                             Allen, Mr. William Henry    1  0.434531  0.000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix
corr_matrix = titanic_dataset[columns_to_scale].corr()  #columns_to_scale = ['PassengerId', 'Survived', 'Pclass', 'Age','SibSp','Parch','Fare'] --> Using only numeric value

# Plot heatmap of correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.show()

# Drop highly correlated features (e.g., correlation > 0.9)
corr_threshold = 0.9
to_drop = [column for column in corr_matrix.columns if any(abs(corr_matrix[column]) > corr_threshold)]
print(to_drop)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %% [markdown]
# # Principal Component Analysis (PCA)

# %%
import pandas as pd

# Load the dataset
titanic_dataset= pd.read_csv("./titanic.csv")  # Replace with actual dataset path
titanic_dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from sklearn.preprocessing import StandardScaler

# Selecting numerical features
numerical_features = titanic_dataset.select_dtypes(include=['float64', 'int64'])  # Drop target if applicable
# Standardizing the features
scaler = StandardScaler()
scaled_data= scaler.fit_transform(numerical_features)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="mean")  # You can also use "median" or "most_frequent"
scaled_data = imputer.fit_transform(scaled_data)

# %%
# manually 
from sklearn.decomposition import PCA

# Choose the number of components
pca = PCA(n_components=5)  # Adjust based on variance explained
pca_features = pca.fit_transform(scaled_data)

# Convert to DataFrame
pca_df = pd.DataFrame(pca_features, columns=[f'PC{i+1}' for i in range(5)])


import matplotlib.pyplot as plt

explained_variance = pca.explained_variance_ratio_

# Plot cumulative variance
plt.figure(figsize=(8,5))
plt.plot(range(1, len(explained_variance)+1), explained_variance.cumsum(), marker='o', linestyle='--')
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("Explained Variance by PCA Components")
plt.show()

# %%
# automate the n component

from sklearn.decomposition import PCA
import numpy as np

# Apply PCA without specifying components (to analyze all)
pca = PCA()
pca.fit(scaled_data)

# Calculate cumulative variance explained
explained_variance = np.cumsum(pca.explained_variance_ratio_)

# Plot the explained variance
plt.figure(figsize=(8,5))
plt.plot(range(1, len(explained_variance) + 1), explained_variance, marker='o', linestyle='--')
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("Choosing the Number of PCA Components")
plt.grid()
plt.show()
